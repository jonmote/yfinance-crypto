# %% [markdown]
# # Comparing Top Meme Cryptos Using Yfinance
#
# The purpose of this notebook is to compare top meme cryptos (DOGE-related) with market caps over 100m. To date, there are currently seven (7) Doge-meme cryptos (DMCs) with a market cap over 100m USD:
#
# - Dogecoin - DOGE
# - SHIBA INU - SHIB
# - Dogelon Mars - ELON
# - Samoyedcoin - SAMO
# - Hoge Finance - HOGE
# - Doge Dash - DOGEDASH
#
# The initial analysis will focus on the two largest coins - DOGE and SHIB
#
# Yfinance is good for quick gathering of historical prices.  However, Yfinance is not supported by Yahoo and it is not clear if/when they will limit data scrapes of this kind in the future.

# %%
import pandas as pd
import datetime as dt
from pandas_datareader import data
import yfinance as yf

# %% [markdown]
# ### Gather information on a single ticker

# %%
doge=yf.Ticker("DOGE-USD")

# %%
doge.info['volume']
# Out:
# 834091776

# %% [markdown]
# Information can be gathered for more currencies one at a time and assembled into a single dataframe for analysis.  The individual tables are then combined for analysis.

# %%
doge=yf.download(
tickers = ['DOGE-USD'],
period = '6mo')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
doge.reset_index(inplace=True)
doge
# Out:
#         Date      Open      High       Low     Close  Adj Close      Volume
# 0 2021-05-22  0.358717  0.360517  0.318169  0.342371   0.342371  5243222352
# 1 2021-05-23  0.342522  0.350863  0.249437  0.308071   0.308071  7143545371
# 2 2021-05-24  0.306715  0.371485  0.296291  0.366162   0.366162  6821088755

# %%
shib=yf.download(
tickers = ['SHIB-USD'],
period = '6mo')
shib.reset_index(inplace=True)
shib.head(2)
# Out:
# [*********************100%***********************]  1 of 1 completed
#         Date      Open     High       Low     Close  Adj Close      Volume
# 0 2021-05-22  0.000008  0.00001  0.000007  0.000008   0.000008  1229821215
# 1 2021-05-23  0.000008  0.00001  0.000007  0.000008   0.000008  1585032040

# %%
df=pd.DataFrame({'DOGE': doge['Close'], 'SHIB': shib['Close']})

# %%
df.head(2)
# Out:
#        DOGE      SHIB
# 0  0.342371  0.000008
# 1  0.308071  0.000008

# %%
df.describe()
# Out:
#              DOGE        SHIB
# count  185.000000  185.000000
# mean     0.258417    0.000017
# std      0.048900    0.000018
# min      0.170801    0.000006
# 25%      0.224126    0.000007
# 50%      0.252016    0.000008
# 75%      0.292226    0.000025
# max      0.423374    0.000080

# %% [markdown]
# ### Scrape Information on Multiple Tickers
#
# This method also allows for multiple currencies, but a bit of wrangling is needed for the final table

# %%
df=yf.download(
tickers = ['DOGE-USD', 'SHIB-USD'],
period = '6mo')
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
df
# Out:
#            Adj Close               Close                High            \
#             DOGE-USD  SHIB-USD  DOGE-USD  SHIB-USD  DOGE-USD  SHIB-USD
# Date
# 2021-05-22  0.342371  0.000008  0.342371  0.000008  0.360517  0.000010
# 2021-05-23  0.308071  0.000008  0.308071  0.000008  0.350863  0.000010
# 2021-05-24  0.366162  0.000011  0.366162  0.000011  0.371485  0.000012
# 2021-05-25  0.346302  0.000009  0.346302  0.000009  0.380010  0.000011
# 2021-05-26  0.353693  0.000010  0.353693  0.000010  0.365920  0.000010
# ...              ...       ...       ...       ...       ...       ...
# 2021-11-18  0.221383  0.000042  0.221383  0.000042  0.241091  0.000049
# 2021-11-19  0.233110  0.000049  0.233110  0.000049  0.236832  0.000052
# 2021-11-20  0.233024  0.000048  0.233024  0.000048  0.235953  0.000050
# 2021-11-21  0.226328  0.000044  0.226328  0.000044  0.233350  0.000048
# 2021-11-22  0.222787  0.000045  0.222787  0.000045  0.225974  0.000046
#
#                  Low                Open                Volume
#             DOGE-USD  SHIB-USD  DOGE-USD  SHIB-USD    DOGE-USD    SHIB-USD
# Date
# 2021-05-22  0.318169  0.000007  0.358717  0.000008  5243222352  1229821215
# 2021-05-23  0.249437  0.000007  0.342522  0.000008  7143545371  1585032040
# 2021-05-24  0.296291  0.000008  0.306715  0.000008  6821088755  2179651359
# 2021-05-25  0.323497  0.000009  0.366041  0.000011  5544552739  1415340765
# 2021-05-26  0.338857  0.000009  0.346396  0.000009  3355793260   994520516
# ...              ...       ...       ...       ...         ...         ...
# 2021-11-18  0.216099  0.000041  0.237556  0.000048  1860661769  3495863723
# 2021-11-19  0.216518  0.000042  0.220995  0.000043  1296123511  4244014798
# 2021-11-20  0.225451  0.000046  0.233174  0.000049   805305660  2406332845
# 2021-11-21  0.225680  0.000044  0.233255  0.000048   751789838  1636858723
# 2021-11-22  0.220133  0.000043  0.225205  0.000044   833902272  1928762624
#
# [185 rows x 12 columns]

# %%
my_list=df.columns.values.tolist()

# %%
my_list
# Out:
# [('Adj Close', 'DOGE-USD'),
#  ('Adj Close', 'SHIB-USD'),
#  ('Close', 'DOGE-USD'),
#  ('Close', 'SHIB-USD'),
#  ('High', 'DOGE-USD'),
#  ('High', 'SHIB-USD'),
#  ('Low', 'DOGE-USD'),
#  ('Low', 'SHIB-USD'),
#  ('Open', 'DOGE-USD'),
#  ('Open', 'SHIB-USD'),
#  ('Volume', 'DOGE-USD'),
#  ('Volume', 'SHIB-USD')]

# %%
df.columns=df.columns.map('-'.join).str.strip('-')

# %%
df.reset_index(drop=False, inplace=True)

# %%
df
# Out:
#           Date  Adj Close-DOGE-USD  Adj Close-SHIB-USD  Close-DOGE-USD  \
# 0   2021-05-22            0.342371            0.000008        0.342371
# 1   2021-05-23            0.308071            0.000008        0.308071
# 2   2021-05-24            0.366162            0.000011        0.366162
# 3   2021-05-25            0.346302            0.000009        0.346302
# 4   2021-05-26            0.353693            0.000010        0.353693
# ..         ...                 ...                 ...             ...
# 180 2021-11-18            0.221383            0.000042        0.221383
# 181 2021-11-19            0.233110            0.000049        0.233110
# 182 2021-11-20            0.233024            0.000048        0.233024
# 183 2021-11-21            0.226328            0.000044        0.226328
# 184 2021-11-22            0.222787            0.000045        0.222787
#
#      Close-SHIB-USD  High-DOGE-USD  High-SHIB-USD  Low-DOGE-USD  Low-SHIB-USD  \
# 0          0.000008       0.360517       0.000010      0.318169      0.000007
# 1          0.000008       0.350863       0.000010      0.249437      0.000007
# 2          0.000011       0.371485       0.000012      0.296291      0.000008
# 3          0.000009       0.380010       0.000011      0.323497      0.000009
# 4          0.000010       0.365920       0.000010      0.338857      0.000009
# ..              ...            ...            ...           ...           ...
# 180        0.000042       0.241091       0.000049      0.216099      0.000041
# 181        0.000049       0.236832       0.000052      0.216518      0.000042
# 182        0.000048       0.235953       0.000050      0.225451      0.000046
# 183        0.000044       0.233350       0.000048      0.225680      0.000044
# 184        0.000045       0.225974       0.000046      0.220133      0.000043
#
#      Open-DOGE-USD  Open-SHIB-USD  Volume-DOGE-USD  Volume-SHIB-USD
# 0         0.358717       0.000008       5243222352       1229821215
# 1         0.342522       0.000008       7143545371       1585032040
# 2         0.306715       0.000008       6821088755       2179651359
# 3         0.366041       0.000011       5544552739       1415340765
# 4         0.346396       0.000009       3355793260        994520516
# ..             ...            ...              ...              ...
# 180       0.237556       0.000048       1860661769       3495863723
# 181       0.220995       0.000043       1296123511       4244014798
# 182       0.233174       0.000049        805305660       2406332845
# 183       0.233255       0.000048        751789838       1636858723
# 184       0.225205       0.000044        833902272       1928762624
#
# [185 rows x 13 columns]

# %% [markdown]
# ### Visualize Several Metrics on Closing Price

# %%
df1=df[['Close-DOGE-USD', 'Close-SHIB-USD']]

# %%
df1.head(5)
# Out:
#    Close-DOGE-USD  Close-SHIB-USD
# 0        0.342371        0.000008
# 1        0.308071        0.000008
# 2        0.366162        0.000011
# 3        0.346302        0.000009
# 4        0.353693        0.000010

# %%
df1.describe()
# Out:
#        Close-DOGE-USD  Close-SHIB-USD
# count      185.000000      185.000000
# mean         0.258417        0.000017
# std          0.048900        0.000018
# min          0.170801        0.000006
# 25%          0.224126        0.000007
# 50%          0.252016        0.000008
# 75%          0.292226        0.000025
# max          0.423374        0.000080

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
my_crypto = df1
plt.figure(figsize = (12.2, 4.5))
for c in my_crypto.columns.values:
   plt.plot(my_crypto[c], label = c)
plt.title('DOGE VS SHIB')
plt.xlabel('Days')
plt.ylabel(' Crypto Price ($)')
plt.legend(my_crypto.columns.values, loc= 'upper left')
plt.show()

# %%
#Scale the data
#the min-max scaler method scales the dataset so that all the input features lie between 0 and 100 inclusive
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(0, 100))
scaled = min_max_scaler.fit_transform(df1)
scaled
# Out:
# array([[ 67.92887174,   2.70270247],
#        [ 54.34863961,   2.70270247],
#        [ 77.34833276,   6.75675679],
#        [ 69.4852597 ,   4.05405432],
#        [ 72.41154469,   5.40540494],
#        [ 64.19688226,   4.05405432],
#        [ 55.58947384,   2.70270247],
#        [ 52.38446132,   2.70270247],
#        [ 52.03367432,   2.70270247],
#        [ 61.37195487,   4.05405432],
#        [ 78.8983844 ,   4.05405432],
#        [100.        ,   4.05405432],
#        [ 90.73099425,   5.40540494],
#        [ 81.37133304,   4.05405432],
#        [ 79.72982357,   2.70270247],
#        [ 79.58333292,   4.05405432],
#        [ 63.44661177,   2.70270247],
#        [ 62.11511027,   1.35135124],
#        [ 35.99157328,  62.16216296],
#        [ 36.46906319,  63.51351481],
#        [ 33.9418723 ,  63.51351481],
#        [ 26.30843498,  56.75676048],
#        [ 26.40266569,  56.75676048],
#        [ 20.02668808,  48.64864938],
#        [ 24.66969839,  58.10810741],
#        [ 24.63565096,  56.75676048],
#        [ 21.98453594,  51.35135308],
#        [ 20.58266819,  52.03335614]])

# %%
df1_scale = pd.DataFrame(scaled, columns = df1.columns)

# %%
#Visualize the scaled data
my_crypto = df1_scale
plt.figure(figsize=(12.4, 4.5))
for c in my_crypto.columns.values:
   plt.plot(my_crypto[c], label=c)
plt.title('DOGE VS SHIB (Scaled Graph)')
plt.xlabel('Days')
plt.ylabel('Crypto Scaled Price ($)')
plt.legend(my_crypto.columns.values, loc = 'upper left')
plt.show()

# %%
DSR = df1.pct_change(1)
DSR
# Out:
#      Close-DOGE-USD  Close-SHIB-USD
# 0               NaN             NaN
# 1         -0.100184        0.000000
# 2          0.188564        0.375000
# 3         -0.054238       -0.181818
# 4          0.021343        0.111111
# ..              ...             ...
# 180       -0.067810       -0.125000
# 181        0.052972        0.166667
# 182       -0.000369       -0.020408
# 183       -0.028735       -0.083333
# 184       -0.015644        0.011470
#
# [185 rows x 2 columns]

# %%
plt.figure(figsize=(12, 4.5))
for c in DSR.columns.values:
   plt.plot(DSR.index, DSR[c], label = c, lw = 2, alpha = .7)
plt.title('DOGE VS SHIB - Daily Simple Returns')
plt.ylabel('Percentage (in decimal form')
plt.xlabel('Days')
plt.legend(DSR.columns.values, loc= 'upper right')
plt.show()

# %%
print('The cryptocurrency volatility:')
DSR.std()
# Out:
# The cryptocurrency volatility:
# Close-DOGE-USD    0.066505
# Close-SHIB-USD    0.123678
# dtype: float64

# %%
DSR.mean()
# Out:
# Close-DOGE-USD   -0.000101
# Close-SHIB-USD    0.016044
# dtype: float64

# %%
DSR.corr()
# Out:
#                 Close-DOGE-USD  Close-SHIB-USD
# Close-DOGE-USD         1.00000         0.38726
# Close-SHIB-USD         0.38726         1.00000

# %%
import seaborn as sns
plt.subplots(figsize= (11,11))
sns.heatmap(DSR.corr(), annot= True, fmt= '.2%')

# %%
DCSR = (DSR+1).cumprod()
DCSR
# Out:
#      Close-DOGE-USD  Close-SHIB-USD
# 0               NaN             NaN
# 1          0.899816        1.000000
# 2          1.069489        1.375000
# 3          1.011482        1.125000
# 4          1.033069        1.250000
# ..              ...             ...
# 180        0.646617        5.250000
# 181        0.680870        6.125000
# 182        0.680618        6.000000
# 183        0.661061        5.500000
# 184        0.650719        5.563085
#
# [185 rows x 2 columns]

# %%
plt.figure(figsize=(12.2, 4.5))
for c in DCSR.columns.values:
  plt.plot(DCSR.index, DCSR[c], lw=2, label= c)
plt.title('DOGE VS SHIB - Daily Cumulative Simple Return')
plt.xlabel('Days')
plt.ylabel('Growth of $1 investment')
plt.legend(DCSR.columns.values, loc = 'upper left', fontsize = 10)
plt.show()
